# %% [markdown]
# ### **Estimación de precios de casas**
#
# Se utiliza un dataset con diversas características de casas. A partir de estos datos y aplicando ingenieria de características se busca predecir el precio de venta de las casas aplicando un modelo de machine learning.
#
# El dataset se encuentra disponible en Kaggle: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %% [markdown]
# ### **1. Importación de librerias y dataset**
#
# Se importan las librerias a ser utilizadas y el dataset a analizar

# %%
# librerias 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import ColumnTransformer
from lightgbm import LGBMRegressor
import lightgbm as lgb
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# importar el dataset de train
df = pd.read_csv('train.csv')
df.head(10).T
# Out:
#                     0       1       2        3       4       5       6  \
# Id                  1       2       3        4       5       6       7
# MSSubClass         60      20      60       70      60      50      20
# MSZoning           RL      RL      RL       RL      RL      RL      RL
# LotFrontage      65.0    80.0    68.0     60.0    84.0    85.0    75.0
# LotArea          8450    9600   11250     9550   14260   14115   10084
# ...               ...     ...     ...      ...     ...     ...     ...
# MoSold              2       5       9        2      12      10       8
# YrSold           2008    2007    2008     2006    2008    2009    2007
# SaleType           WD      WD      WD       WD      WD      WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal  Normal  Normal
# SalePrice      208500  181500  223500   140000  250000  143000  307000
#
#                     7        8       9
# Id                  8        9      10
# ...

# %%
# importar el dataset de test
df_test = pd.read_csv('test.csv')
df_test.head(10).T
# Out:
#                     0       1       2       3       4       5       6       7  \
# Id               1461    1462    1463    1464    1465    1466    1467    1468
# MSSubClass         20      20      60      60     120      60      20      60
# MSZoning           RH      RL      RL      RL      RL      RL      RL      RL
# LotFrontage      80.0    81.0    74.0    78.0    43.0    75.0     NaN    63.0
# LotArea         11622   14267   13830    9978    5005   10000    7980    8402
# ...               ...     ...     ...     ...     ...     ...     ...     ...
# MiscVal             0   12500       0       0       0       0     500       0
# MoSold              6       6       3       6       1       4       3       5
# YrSold           2010    2010    2010    2010    2010    2010    2010    2010
# SaleType           WD      WD      WD      WD      WD      WD      WD      WD
# SaleCondition  Normal  Normal  Normal  Normal  Normal  Normal  Normal  Normal
#
#                     8       9
# ...

# %% [markdown]
# ### **2. Limpieza de datos**
#
# En esta sección se verifica la presencia de valores duplicados, outliers, nulos en el dataset con los datos de entrenamiento
#
# ### **2.1. Verificacion de tipo de datos**

# %%
# info del df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# info del df
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
# tipos de datos del dataframe
print("Los tipos de datos del dataframe son:")
print(df.dtypes)
print(df_test.dtypes)
# Out:
# Los tipos de datos del dataframe son:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %% [markdown]
# Se extraen todas las columnas del tipo "object" para verificar los valores unicos de cada columna.

# %%
# extraer las columnas tipo object
object_columns = df.select_dtypes(include=['object'])

# identificar sus valores unicos 
for column in object_columns:
    unique_values = object_columns[column].unique()
    print(f"Columna '{column}': {unique_values}")
# Out:
# Columna 'MSZoning': ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Columna 'Street': ['Pave' 'Grvl']
# Columna 'Alley': [nan 'Grvl' 'Pave']
# Columna 'LotShape': ['Reg' 'IR1' 'IR2' 'IR3']
# Columna 'LandContour': ['Lvl' 'Bnk' 'Low' 'HLS']
# Columna 'Utilities': ['AllPub' 'NoSeWa']
# Columna 'LotConfig': ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# Columna 'LandSlope': ['Gtl' 'Mod' 'Sev']
# Columna 'Neighborhood': ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Columna 'Condition1': ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Columna 'Condition2': ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# Columna 'BldgType': ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# Columna 'HouseStyle': ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# ...

# %% [markdown]
# En cada columna que fue identificada como "object" no se observa que hayan entre ellos simbolos como ?, $.
#
# A continuacion se verifica si las columnas no se encuentran vacias.

# %%
# verificar celdas nulas o con espacios 
empty_columns = object_columns.apply(lambda col: col.isna().all() or col.str.strip().eq('').all())

# resultado
print("Columnas de tipo object vacías:")
print(empty_columns[empty_columns].index.tolist())
# Out:
# Columnas de tipo object vacías:
# []

# %% [markdown]
# No se encuentran columnas que esten vacias.
#
# Entonces se procede a realizar el cambio de las columnas object al tipo string

# %%
# objeto a category
df = df.astype({col: 'string' for col in df.select_dtypes(include='object').columns})

# resultado
df.dtypes
# Out:
# Id                        int64
# MSSubClass                int64
# MSZoning         string[python]
# LotFrontage             float64
# LotArea                   int64
#                       ...
# MoSold                    int64
# YrSold                    int64
# SaleType         string[python]
# SaleCondition    string[python]
# SalePrice                 int64
# Length: 81, dtype: object

# %% [markdown]
# A modo de verificacion, se analizan los valores unicos de las columnas con formato int64 y float64 para verificar que hayan sido identificadas de manera correcta.

# %%
# extraer las columnas tipo int
numerical_columns = df.select_dtypes(include=['int64','float64'])

# identificar sus valores unicos 
for column in numerical_columns:
    unique_values = numerical_columns[column].unique()
    print(f"Columna '{column}': {unique_values}")
# Out:
# Columna 'Id': [   1    2    3 ... 1458 1459 1460]
# Columna 'MSSubClass': [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# Columna 'LotFrontage': [ 65.  80.  68.  60.  84.  85.  75.  nan  51.  50.  70.  91.  72.  66.
#  101.  57.  44. 110.  98.  47. 108. 112.  74. 115.  61.  48.  33.  52.
#  100.  24.  89.  63.  76.  81.  95.  69.  21.  32.  78. 121. 122.  40.
#  105.  73.  77.  64.  94.  34.  90.  55.  88.  82.  71. 120. 107.  92.
#  134.  62.  86. 141.  97.  54.  41.  79. 174.  99.  67.  83.  43. 103.
#   93.  30. 129. 140.  35.  37. 118.  87. 116. 150. 111.  49.  96.  59.
#   36.  56. 102.  58.  38. 109. 130.  53. 137.  45. 106. 104.  42.  39.
#  144. 114. 128. 149. 313. 168. 182. 138. 160. 152. 124. 153.  46.]
# Columna 'LotArea': [ 8450  9600 11250 ... 17217 13175  9717]
# Columna 'OverallQual': [ 7  6  8  5  9  4 10  3  1  2]
# Columna 'OverallCond': [5 8 6 7 4 2 3 9 1]
# Columna 'YearBuilt': [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
# ...

# %% [markdown]
# Todos los datos del tipo numerico fueron identificados correctamente.

# %% [markdown]
# ### **2.2. Verificacion de valores duplicados**
#
# Se procede a verificar si hay datos duplicados.

# %%
# identificar duplicados
duplicados = df.duplicated()

# contar el número de duplicados
num_duplicados = duplicados.sum()
print(f"Número de registros duplicados: {num_duplicados}")
# Out:
# Número de registros duplicados: 0

# %% [markdown]
# Tampoco el dataset de entrenamiento contiene datos duplicados.

# %% [markdown]
# ### **2.3. Consistencia de variables categoricas**
#
# Se verifica entonces la consistencia de las variables categoricas, que la mismas palabras no se encuentren con diferentes formatos y por lo tanto se decide normalizar a minusculas. La siguiente porción de código fue elaborado con chat gpt para borrar espacios entre palabras y convertir todos a minusculas.

# %%
# función para corregir inconsistencias
def clean_categorical_column(column):
    if column.isna().all():
        # no se hace nada si toda la columna es NA
        return column  
    # limpiar espacios, y normalizar a minúsculas
    cleaned_column = column.str.strip().str.lower()
    return cleaned_column

# aplicar la funcion al df
for col in df.select_dtypes(include='string').columns:
    df[col] = clean_categorical_column(df[col])

# resultado
print("DataFrame:")
print(df)
# Out:
# DataFrame:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       rl         65.0     8450   pave  <NA>      reg
# 1        2          20       rl         80.0     9600   pave  <NA>      reg
# 2        3          60       rl         68.0    11250   pave  <NA>      ir1
# 3        4          70       rl         60.0     9550   pave  <NA>      ir1
# 4        5          60       rl         84.0    14260   pave  <NA>      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       rl         62.0     7917   pave  <NA>      reg
# 1456  1457          20       rl         85.0    13175   pave  <NA>      reg
# 1457  1458          70       rl         66.0     9042   pave  <NA>      reg
# 1458  1459          20       rl         68.0     9717   pave  <NA>      reg
# 1459  1460          20       rl         75.0     9937   pave  <NA>      reg
#
# ...

# %%
# df
df.dtypes
# Out:
# Id                        int64
# MSSubClass                int64
# MSZoning         string[python]
# LotFrontage             float64
# LotArea                   int64
#                       ...
# MoSold                    int64
# YrSold                    int64
# SaleType         string[python]
# SaleCondition    string[python]
# SalePrice                 int64
# Length: 81, dtype: object

# %% [markdown]
# ### **2.4. Análisis de los valores faltantes**
#
# Se verifica la cantidad y porcentaje de valores faltantes en el dataframe, además de ser necesario se rellenan los datos faltantes.

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# PoolQC                         7     1453    99.52
# MiscFeature                   54     1406    96.30
# Alley                         91     1369    93.77
# Fence                        281     1179    80.75
# MasVnrType                   588      872    59.73
# FireplaceQu                  770      690    47.26
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtFinType2                1422       38     2.60
# BsmtExposure                1422       38     2.60
# BsmtFinType1                1423       37     2.53
# BsmtCond                    1423       37     2.53
# BsmtQual                    1423       37     2.53
# ...

# %% [markdown]
# Uno de los datos faltantes con mayor cantidad es PoolQC, que es la calidad de las piscinas de las casas, con los posibles valores:
# Ex	Excellent
# Gd	Good
# TA	Average/Typical
# Fa	Fair
# NA	No Pool
# El 99% de los datos no contiene esta informacion.

# %%
# filtrar
df.loc[df.isnull()['PoolQC']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       rl         65.0     8450   pave  <NA>      reg
# 1        2          20       rl         80.0     9600   pave  <NA>      reg
# 2        3          60       rl         68.0    11250   pave  <NA>      ir1
# 3        4          70       rl         60.0     9550   pave  <NA>      ir1
# 4        5          60       rl         84.0    14260   pave  <NA>      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       rl         62.0     7917   pave  <NA>      reg
# 1456  1457          20       rl         85.0    13175   pave  <NA>      reg
# 1457  1458          70       rl         66.0     9042   pave  <NA>      reg
# 1458  1459          20       rl         68.0     9717   pave  <NA>      reg
# 1459  1460          20       rl         75.0     9937   pave  <NA>      reg
#
# ...

# %% [markdown]
# Verificar si las columnas de PoolQC son nulas y las columnas de PoolArea son 0, esto podria implicar que las casas no tienen piscina.

# %%
# pool area 0
df.loc[df['PoolArea']==0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       rl         65.0     8450   pave  <NA>      reg
# 1        2          20       rl         80.0     9600   pave  <NA>      reg
# 2        3          60       rl         68.0    11250   pave  <NA>      ir1
# 3        4          70       rl         60.0     9550   pave  <NA>      ir1
# 4        5          60       rl         84.0    14260   pave  <NA>      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       rl         62.0     7917   pave  <NA>      reg
# 1456  1457          20       rl         85.0    13175   pave  <NA>      reg
# 1457  1458          70       rl         66.0     9042   pave  <NA>      reg
# 1458  1459          20       rl         68.0     9717   pave  <NA>      reg
# 1459  1460          20       rl         75.0     9937   pave  <NA>      reg
#
# ...

# %%
# pool area no 0
df.loc[df['PoolArea']!=0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       rl        174.0    25419   pave  <NA>      reg
# 810    811          20       rl         78.0    10140   pave  <NA>      reg
# 1170  1171          80       rl         76.0     9880   pave  <NA>      reg
# 1182  1183          60       rl        160.0    15623   pave  <NA>      ir1
# 1298  1299          60       rl        313.0    63887   pave  <NA>      ir3
# 1386  1387          60       rl         80.0    16692   pave  <NA>      ir1
# 1423  1424          80       rl          NaN    19690   pave  <NA>      ir1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          lvl    allpub  ...      512     ex  gdprv        <NA>       0
# 810          lvl    allpub  ...      648     fa  gdprv        <NA>       0
# 1170         lvl    allpub  ...      576     gd  gdprv        <NA>       0
# ...

# %% [markdown]
# Se rellenan los datos faltantes de PoolQC con No Pool, ya que coincidentemente, tampoco cuenta con los datos de pool area y esto implicaria que la casa no cuenta con piscina.

# %%
# rellenar
df.loc[(df['PoolArea'] == 0) & (df['PoolQC'].isnull()), 'PoolQC'] = 'No Pool'

df.loc[df.isnull()['PoolQC']]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# MiscFeature                   54     1406    96.30
# Alley                         91     1369    93.77
# Fence                        281     1179    80.75
# MasVnrType                   588      872    59.73
# FireplaceQu                  770      690    47.26
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtExposure                1422       38     2.60
# BsmtFinType2                1422       38     2.60
# BsmtFinType1                1423       37     2.53
# BsmtCond                    1423       37     2.53
# BsmtQual                    1423       37     2.53
# MasVnrArea                  1452        8     0.55
# ...

# %% [markdown]
# Otra columna con gran cantidad de datos faltantes es MiscFeature, que se refiere a caracteristicas extras que tiene la casa y tiene valores como:
# MiscFeature: Miscellaneous feature not covered in other categories
# Elev	Elevator
# Gar2	2nd Garage (if not described in garage section)
# Othr	Other
# Shed	Shed (over 100 SF)
# TenC	Tennis Court
# NA	None

# %%
# filtrar
df.loc[df.isnull()['MiscFeature']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       rl         65.0     8450   pave  <NA>      reg
# 1        2          20       rl         80.0     9600   pave  <NA>      reg
# 2        3          60       rl         68.0    11250   pave  <NA>      ir1
# 3        4          70       rl         60.0     9550   pave  <NA>      ir1
# 4        5          60       rl         84.0    14260   pave  <NA>      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  1455          20       fv         62.0     7500   pave  pave      reg
# 1455  1456          60       rl         62.0     7917   pave  <NA>      reg
# 1456  1457          20       rl         85.0    13175   pave  <NA>      reg
# 1458  1459          20       rl         68.0     9717   pave  <NA>      reg
# 1459  1460          20       rl         75.0     9937   pave  <NA>      reg
#
# ...

# %% [markdown]
# Para tomar la decision de si se elimina o mantiene los datos de esta columna, se busca a continuacion identificar si hay alguna relacion con el precio de venta de las casas. Asi, se convierte la variable miscfeature a una binaria, tomando el valor de 1 cuando la casa cuenta con estas caracteristicas extras y 0 cuando no las tiene. Luego, se verifica la correlacion con el precio de venta.

# %%
# convertir MiscFeature en variable binaria
df_corr = df[['MiscFeature', 'SalePrice']].copy()
df_corr['HasMiscFeature'] = df_corr['MiscFeature'].notna().astype(int)

# correlacion entre presencia o ausencia de features con precio
correlation = df_corr['HasMiscFeature'].corr(df_corr['SalePrice'])
print(f"Correlación entre 'HasMiscFeature' y el precio: {correlation}")
# Out:
# Correlación entre 'HasMiscFeature' y el precio: -0.07229811288612352

# %% [markdown]
# Considerando que se tiene una correlacion debil, se procede a utilizarlo como una variable binaria, es decir, si la casa cuenta con caracteristicas extras tomara un valor de 1, caso contrario sera 0.

# %%
# nueva columna binaria basada en la presencia o ausencia de MiscFeature
df['HasMiscFeature'] = df['MiscFeature'].notna().astype(int)

# verificar
df[['MiscFeature', 'HasMiscFeature']].head()
# Out:
#   MiscFeature  HasMiscFeature
# 0        <NA>               0
# 1        <NA>               0
# 2        <NA>               0
# 3        <NA>               0
# 4        <NA>               0

# %% [markdown]
# Al crearse una nueva columna se condensa la informacion relevante, sin embargo, la columna original todavia queda con datos faltantes, asi que de igual forma esto sera rellenado con una categoria nueva denominada "unknown", ya que la variable es del tipo categorica.

# %%
# MiscFeature
df['MiscFeature'].unique()
# Out:
# <StringArray>
# [<NA>, 'shed', 'gar2', 'othr', 'tenc']
# Length: 5, dtype: string

# %%
# rellenar
df['MiscFeature'] = df['MiscFeature'].fillna('Unknown')

# resultado
df['MiscFeature'].unique()
# Out:
# <StringArray>
# ['Unknown', 'shed', 'gar2', 'othr', 'tenc']
# Length: 5, dtype: string

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# Alley                         91     1369    93.77
# Fence                        281     1179    80.75
# MasVnrType                   588      872    59.73
# FireplaceQu                  770      690    47.26
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtExposure                1422       38     2.60
# BsmtFinType2                1422       38     2.60
# BsmtCond                    1423       37     2.53
# BsmtFinType1                1423       37     2.53
# BsmtQual                    1423       37     2.53
# MasVnrArea                  1452        8     0.55
# Electrical                  1459        1     0.07

# %% [markdown]
# La siguiente columna a analizar es la de Alley, que representa el tipo de entrada a la casa, tomando los siguientes valores
# Grvl	Gravel
# Pave	Paved
# NA 	No alley access
#
# El 93% de la columna no contiene datos.

# %%
# filtrar
df.loc[df.isnull()['Alley']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       rl         65.0     8450   pave  <NA>      reg
# 1        2          20       rl         80.0     9600   pave  <NA>      reg
# 2        3          60       rl         68.0    11250   pave  <NA>      ir1
# 3        4          70       rl         60.0     9550   pave  <NA>      ir1
# 4        5          60       rl         84.0    14260   pave  <NA>      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       rl         62.0     7917   pave  <NA>      reg
# 1456  1457          20       rl         85.0    13175   pave  <NA>      reg
# 1457  1458          70       rl         66.0     9042   pave  <NA>      reg
# 1458  1459          20       rl         68.0     9717   pave  <NA>      reg
# 1459  1460          20       rl         75.0     9937   pave  <NA>      reg
#
# ...

# %% [markdown]
# Nuevamente, buscaremos una correlacion entre alley y el precio de venta de las casas.

# %%
# convertir MiscFeature en variable binaria
df_corr = df[['Alley', 'SalePrice']].copy()
df_corr['HasAlley'] = df_corr['Alley'].notna().astype(int)

# correlacion entre presencia o ausencia de features con precio
correlation = df_corr['HasAlley'].corr(df_corr['SalePrice'])
print(f"Correlación entre 'HasAlley' y el precio: {correlation}")
# Out:
# Correlación entre 'HasAlley' y el precio: -0.12361124617957109

# %%
# unicos
df['Alley'].unique()
# Out:
# <StringArray>
# [<NA>, 'grvl', 'pave']
# Length: 3, dtype: string

# %% [markdown]
# La correlacion entre alley y el precio de las casas es debil, sin embargo como se trata de un gran volumen de datos, se procedera de manera similar a la caracteristica anterior. Se creara la variable Has_Alley y se rellenara con 1 cuando se tenga y con 0 en caso de no poseerlo.

# %%
# nueva columna binaria basada en la presencia o ausencia de alley
df['Has_Alley'] = df['Alley'].notna().astype(int)

# verificar
df[['Alley', 'Has_Alley']].head()
# Out:
#   Alley  Has_Alley
# 0  <NA>          0
# 1  <NA>          0
# 2  <NA>          0
# 3  <NA>          0
# 4  <NA>          0

# %% [markdown]
# Tambien, los datos faltantes se rellenan con la palabra unknown.

# %%
# rellenar
df['Alley'] = df['Alley'].fillna('Unknown')

# resultado
df['Alley'].unique()
# Out:
# <StringArray>
# ['Unknown', 'grvl', 'pave']
# Length: 3, dtype: string

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# Fence                        281     1179    80.75
# MasVnrType                   588      872    59.73
# FireplaceQu                  770      690    47.26
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtExposure                1422       38     2.60
# BsmtFinType2                1422       38     2.60
# BsmtQual                    1423       37     2.53
# BsmtCond                    1423       37     2.53
# BsmtFinType1                1423       37     2.53
# MasVnrArea                  1452        8     0.55
# Electrical                  1459        1     0.07

# %% [markdown]
# La siguiente columna a analizar es Fence

# %%
# filtrar
df.loc[df.isnull()['Fence']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       rl         65.0     8450   pave  Unknown
# 1        2          20       rl         80.0     9600   pave  Unknown
# 2        3          60       rl         68.0    11250   pave  Unknown
# 3        4          70       rl         60.0     9550   pave  Unknown
# 4        5          60       rl         84.0    14260   pave  Unknown
# ...    ...         ...      ...          ...      ...    ...      ...
# 1453  1454          20       rl         90.0    17217   pave  Unknown
# 1454  1455          20       fv         62.0     7500   pave     pave
# 1455  1456          60       rl         62.0     7917   pave  Unknown
# 1458  1459          20       rl         68.0     9717   pave  Unknown
# 1459  1460          20       rl         75.0     9937   pave  Unknown
#
#      LotShape LandContour Utilities  ... Fence MiscFeature MiscVal MoSold  \
# ...

# %%
# unicos
df['Fence'].unique()
# Out:
# <StringArray>
# [<NA>, 'mnprv', 'gdwo', 'gdprv', 'mnww']
# Length: 5, dtype: string

# %%
# convertir MiscFeature en variable binaria
df_corr = df[['Fence', 'SalePrice']].copy()
df_corr['HasFence'] = df_corr['Fence'].notna().astype(int)

# correlacion entre presencia o ausencia de features con precio
correlation = df_corr['HasFence'].corr(df_corr['SalePrice'])
print(f"Correlación entre 'HasFence' y el precio: {correlation}")
# Out:
# Correlación entre 'HasFence' y el precio: -0.17218394403812115

# %% [markdown]
# Tambien presenta una correlacion baja, sin embargo se busca convertirlo a una variable binaria, indicando con 1 la presencia y 0 la ausencia.

# %%
# nueva columna binaria basada en la presencia o ausencia de fence
df['Has_Fence'] = df['Fence'].notna().astype(int)

# verificar
df[['Fence', 'Has_Fence']].head()
# Out:
#   Fence  Has_Fence
# 0  <NA>          0
# 1  <NA>          0
# 2  <NA>          0
# 3  <NA>          0
# 4  <NA>          0

# %% [markdown]
# Los datos faltantes en la columna original se rellenan con unknown.

# %%
# rellenar
df['Fence'] = df['Fence'].fillna('Unknown')

# resultado
df['Fence'].unique()
# Out:
# <StringArray>
# ['Unknown', 'mnprv', 'gdwo', 'gdprv', 'mnww']
# Length: 5, dtype: string

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# MasVnrType                   588      872    59.73
# FireplaceQu                  770      690    47.26
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtExposure                1422       38     2.60
# BsmtFinType2                1422       38     2.60
# BsmtQual                    1423       37     2.53
# BsmtCond                    1423       37     2.53
# BsmtFinType1                1423       37     2.53
# MasVnrArea                  1452        8     0.55
# Electrical                  1459        1     0.07

# %% [markdown]
# Se procede a analizar MasVnrType.

# %%
# filtrar
df.loc[df.isnull()['MasVnrType']]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 1        2          20       rl         80.0     9600   pave  Unknown
# 3        4          70       rl         60.0     9550   pave  Unknown
# 5        6          50       rl         85.0    14115   pave  Unknown
# 8        9          50       rm         51.0     6120   pave  Unknown
# 9       10         190       rl         50.0     7420   pave  Unknown
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  1455          20       fv         62.0     7500   pave     pave
# 1455  1456          60       rl         62.0     7917   pave  Unknown
# 1457  1458          70       rl         66.0     9042   pave  Unknown
# 1458  1459          20       rl         68.0     9717   pave  Unknown
# 1459  1460          20       rl         75.0     9937   pave  Unknown
#
#      LotShape LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold  \
# ...

# %% [markdown]
# Se aplica el mismo metodo visto anteriormente.

# %%
# unicos
df['MasVnrType'].unique()
# Out:
# <StringArray>
# ['brkface', <NA>, 'stone', 'brkcmn']
# Length: 4, dtype: string

# %%
# convertir MasVnrType en variable binaria
df_corr = df[['MasVnrType', 'SalePrice']].copy()
df_corr['HasMasVnrType'] = df_corr['MasVnrType'].notna().astype(int)

# correlacion entre presencia o ausencia de features con precio
correlation = df_corr['HasMasVnrType'].corr(df_corr['SalePrice'])
print(f"Correlación entre 'HasMasVnrType' y el precio: {correlation}")
# Out:
# Correlación entre 'HasMasVnrType' y el precio: 0.3674563651932487

# %% [markdown]
# La correlacion de MasWnrType es positiva y moderamente debil, pero puede tener un impacto en el precio. Los datos faltantes representan un 59% del total y la variable en si representa el tipo de revestimiento de mampostería

# %%
# nueva columna binaria basada en la presencia o ausencia de vnrtype
df['HasMasVnrType'] = df['MasVnrType'].notna().astype(int)

# verificar
df[['MasVnrType', 'HasMasVnrType']].head()
# Out:
#   MasVnrType  HasMasVnrType
# 0    brkface              1
# 1       <NA>              0
# 2    brkface              1
# 3       <NA>              0
# 4    brkface              1

# %%
# rellenar
df['MasVnrType'] = df['MasVnrType'].fillna('Unknown')

# resultado
df['MasVnrType'].unique()
# Out:
# <StringArray>
# ['brkface', 'Unknown', 'stone', 'brkcmn']
# Length: 4, dtype: string

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# FireplaceQu                  770      690    47.26
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtExposure                1422       38     2.60
# BsmtFinType2                1422       38     2.60
# BsmtQual                    1423       37     2.53
# BsmtCond                    1423       37     2.53
# BsmtFinType1                1423       37     2.53
# MasVnrArea                  1452        8     0.55
# Electrical                  1459        1     0.07

# %% [markdown]
# Por ultimo, FireplaceQu representa la calidad de la chimenea en las casas y nuevamente, esta variable tiene cierta correlacion con el precio.

# %%
# unicos
df['FireplaceQu'].unique()
# Out:
# <StringArray>
# [<NA>, 'ta', 'gd', 'fa', 'ex', 'po']
# Length: 6, dtype: string

# %%
# convertir MiscFeature en variable binaria
df_corr = df[['FireplaceQu', 'SalePrice']].copy()
df_corr['HasFireplaceQu'] = df_corr['FireplaceQu'].notna().astype(int)

# correlacion entre presencia o ausencia de features con precio
correlation = df_corr['HasFireplaceQu'].corr(df_corr['SalePrice'])
print(f"Correlación entre 'HasFireplaceQu' y el precio: {correlation}")
# Out:
# Correlación entre 'HasFireplaceQu' y el precio: 0.4719080685164924

# %%
# nueva columna binaria basada en la presencia o ausencia de vnrtype
df['HasFireplaceQu'] = df['FireplaceQu'].notna().astype(int)

# verificar
df[['FireplaceQu', 'HasFireplaceQu']].head()
# Out:
#   FireplaceQu  HasFireplaceQu
# 0        <NA>               0
# 1          ta               1
# 2          ta               1
# 3          gd               1
# 4          ta               1

# %%
# rellenar
df['FireplaceQu'] = df['FireplaceQu'].fillna('Unknown')

# resultado
df['FireplaceQu'].unique()
# Out:
# <StringArray>
# ['Unknown', 'ta', 'gd', 'fa', 'ex', 'po']
# Length: 6, dtype: string

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
#               datos sin NAs en q  Na en q  Na en %
# LotFrontage                 1201      259    17.74
# GarageType                  1379       81     5.55
# GarageYrBlt                 1379       81     5.55
# GarageFinish                1379       81     5.55
# GarageQual                  1379       81     5.55
# GarageCond                  1379       81     5.55
# BsmtExposure                1422       38     2.60
# BsmtFinType2                1422       38     2.60
# BsmtQual                    1423       37     2.53
# BsmtCond                    1423       37     2.53
# BsmtFinType1                1423       37     2.53
# MasVnrArea                  1452        8     0.55
# Electrical                  1459        1     0.07

# %% [markdown]
# Los datos faltantes restantes representan menos del 20% del dataset total, por esa razon se procede a eliminarlos.

# %%
# eliminar filas
df = df.dropna(subset=['LotFrontage'])
df = df.dropna(subset=['GarageType'])
df = df.dropna(subset=['GarageYrBlt'])
df = df.dropna(subset=['GarageFinish'])
df = df.dropna(subset=['GarageQual'])
df = df.dropna(subset=['GarageCond'])
df = df.dropna(subset=['BsmtExposure'])
df = df.dropna(subset=['BsmtFinType2'])
df = df.dropna(subset=['BsmtQual'])
df = df.dropna(subset=['BsmtCond'])
df = df.dropna(subset=['BsmtFinType1'])
df = df.dropna(subset=['MasVnrArea'])
df = df.dropna(subset=['Electrical'])

# %%
# identificacion de datos faltantes con funcion proporcionada en clase
# cantidad de datos completos, sin NA, es decir, el total de datos
qsna=df.shape[0]-df.isnull().sum(axis=0)

# cantidad de datos que si son na
qna=df.isnull().sum(axis=0)

# proporcion de datos con na y sin na
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)

# constuir la tab
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)

# filtrar solo los que tienen NA
na = na[na['Na en q'] > 0]

# ordenar los valores de la tabla
na.sort_values(by='Na en %',ascending=False)
# Out:
# Empty DataFrame
# Columns: [datos sin NAs en q, Na en q, Na en %]
# Index: []

# %%
#df
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       rl         65.0     8450   pave  Unknown      reg
# 1   2          20       rl         80.0     9600   pave  Unknown      reg
# 2   3          60       rl         68.0    11250   pave  Unknown      ir1
# 3   4          70       rl         60.0     9550   pave  Unknown      ir1
# 4   5          60       rl         84.0    14260   pave  Unknown      ir1
#
#   LandContour Utilities  ... MoSold YrSold SaleType SaleCondition SalePrice  \
# 0         lvl    allpub  ...      2   2008       wd        normal    208500
# 1         lvl    allpub  ...      5   2007       wd        normal    181500
# 2         lvl    allpub  ...      9   2008       wd        normal    223500
# 3         lvl    allpub  ...      2   2006       wd       abnorml    140000
# 4         lvl    allpub  ...     12   2008       wd        normal    250000
#
# ...

# %% [markdown]
# ### **3. Exploracion de datos**

# %% [markdown]
# Crear histogramas y boxplots para las variables

# %%
# extraer columnas numericas 
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

# numero de columnas y filas
cols = 10
filas = (len(numerical_columns) // cols) + (len(numerical_columns) % cols > 0)

# crear boxplots 
plt.figure(figsize=(50, 30))
for i, col in enumerate(numerical_columns, 1):
    # ajusta segun la cantidad de columnas
    plt.subplot(filas, cols, i) 
    sns.boxplot(y=df[col], color="lightgreen")
    plt.title(f"Boxplot de {col}")
    plt.tight_layout()

plt.show()

# %% [markdown]
# En los boxplots se logran outliers varias columnas.

# %%
# distribucion de los datos
plt.figure(figsize=(15, 8))

# numero de columnas y filas
cols = 8
filas = (len(numerical_columns) // cols) + (len(numerical_columns) % cols > 0)

for i, col in enumerate(numerical_columns, 1):
    # ajusta segun la cantidad de columnas
    plt.subplot(filas, cols, i)  
    sns.histplot(df[col], kde=True, color="blue", bins=10)  
    plt.title(f"{col}")
    plt.tight_layout()

plt.show()

# %%
# describe
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1094.000000  1094.000000  1094.000000    1094.000000  1094.000000
# mean    727.375686    56.128885    70.759598   10132.346435     6.247715
# std     420.955488    41.976345    24.508859    8212.249621     1.366797
# min       1.000000    20.000000    21.000000    1300.000000     2.000000
# 25%     366.500000    20.000000    60.000000    7606.750000     5.000000
# 50%     723.500000    50.000000    70.000000    9444.500000     6.000000
# 75%    1093.750000    70.000000    80.000000   11387.250000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1094.000000  1094.000000   1094.000000  1094.000000  1094.000000  ...
# mean      5.575868  1972.412249   1985.915905   109.855576   448.191956  ...
# std       1.066500    31.189752     20.930772   190.667459   468.728095  ...
# ...

# %% [markdown]
# A continuacion se grafica un mapa de calor para identificar correlaciones.

# %%
# variables numéricas
numerical_columns = df.select_dtypes(include=['int64','float64'])

# matriz de correlación
correlation_matrix = numerical_columns.corr(method="pearson")

# mapa de calor
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Mapa de calor')
plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa en los graficos de distribucion que la variable SalePrice tiene una distribucion sesgada.

# %%
# unicos
df['SalePrice'].unique()
# Out:
# array([208500, 181500, 223500, 140000, 250000, 143000, 307000, 129900,
#        118000, 129500, 345000, 279500, 132000, 159000, 139000, 325300,
#        139400, 230000, 256300, 134800, 306000, 207500,  68500,  40000,
#        179900, 165500, 277500, 309000, 145000, 153000, 109000, 160000,
#        170000, 141000, 319900, 239686, 249700, 127000, 114500, 110000,
#        385000, 130000, 180500, 172500, 196500, 438780, 124900, 158000,
#        101000, 202500, 317000, 226000,  80000, 225000, 244000, 185000,
#        144900, 107400,  91000, 193500, 153500, 245000, 126500, 260000,
#        174000, 164500,  98600, 163500, 133900, 204750, 214000,  94750,
#         83000, 178000, 198900, 100000, 115000, 190000, 136900, 383970,
#        259500, 176000, 155000, 320000, 163990, 136000, 153900, 181000,
#        150000, 150750, 180000, 171000, 231500, 166000, 204000, 125000,
#        105000, 122000, 372402, 269500, 254900, 412500, 220000, 152000,
# ...

# %%
# crear una copia con el df modificado
df_modified = df.copy()

# %%
# df
df_modified.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       rl         65.0     8450   pave  Unknown      reg
# 1   2          20       rl         80.0     9600   pave  Unknown      reg
# 2   3          60       rl         68.0    11250   pave  Unknown      ir1
# 3   4          70       rl         60.0     9550   pave  Unknown      ir1
# 4   5          60       rl         84.0    14260   pave  Unknown      ir1
#
#   LandContour Utilities  ... MoSold YrSold SaleType SaleCondition SalePrice  \
# 0         lvl    allpub  ...      2   2008       wd        normal    208500
# 1         lvl    allpub  ...      5   2007       wd        normal    181500
# 2         lvl    allpub  ...      9   2008       wd        normal    223500
# 3         lvl    allpub  ...      2   2006       wd       abnorml    140000
# 4         lvl    allpub  ...     12   2008       wd        normal    250000
#
# ...

# %%
# distribución de SalePrice antes
plt.figure(figsize=(10, 6))
sns.histplot(df_modified['SalePrice'], kde=True)
plt.title('Distribución de SalePrice antes de la transformación')
plt.show()

# aplicar logaritmo a SalePrice para normalizar la distribución
df_modified['SalePrice'] = np.log1p(df_modified['SalePrice'])

# distribución de SalePrice después de la transformación
plt.figure(figsize=(10, 6))
sns.histplot(df_modified['SalePrice'], kde=True)
plt.title('Distribución de SalePrice después de la transformación logarítmica')
plt.show()

# %% [markdown]
# Otras variables serán convertidas al cuadrado o al cubo lo que permitirá capturar relaciones no lineales.

# %%
# elegir las features a convertir
polynomial_features = ['GrLivArea', 'TotRmsAbvGrd', '1stFlrSF', '2ndFlrSF']  

# crear el cuadrado y cubo de estas variables
for feature in polynomial_features:
    df_modified[f'{feature}_squared'] = df_modified[feature] ** 2 
    df_modified[f'{feature}_cubed'] = df_modified[feature] ** 3  

# resultados
df_modified[['GrLivArea', 'GrLivArea_squared', 'GrLivArea_cubed', 'TotRmsAbvGrd_squared', 'TotRmsAbvGrd_cubed']].head()
# Out:
#    GrLivArea  GrLivArea_squared  GrLivArea_cubed  TotRmsAbvGrd_squared  \
# 0       1710            2924100       5000211000                    64
# 1       1262            1592644       2009916728                    36
# 2       1786            3189796       5696975656                    36
# 3       1717            2948089       5061868813                    49
# 4       2198            4831204      10618986392                    81
#
#    TotRmsAbvGrd_cubed
# 0                 512
# 1                 216
# 2                 216
# 3                 343
# 4                 729

# %% [markdown]
# ### **4. Implementacion del modelo en el dataset original**
#
# Los datos ya venian divididos en dos archivos csv, uno de train y otro de test, y se utilizara de la misma forma con el modelo.
#
# Inicialmente se realizará el preprocesamiento con el dataset original y se implementará el modelo, posteriormente se utilizará el dataset modificado y nuevamente se implementará un modelo para comparar los rendimientos.

# %%
# tipos
df.dtypes
# Out:
# Id                         int64
# MSSubClass                 int64
# MSZoning          string[python]
# LotFrontage              float64
# LotArea                    int64
#                        ...
# HasMiscFeature             int32
# Has_Alley                  int32
# Has_Fence                  int32
# HasMasVnrType              int32
# HasFireplaceQu             int32
# Length: 86, dtype: object

# %%
# df
df.shape
# Out:
# (1094, 86)

# %% [markdown]
# Los datos de entrenamiento tienen 1094 filas y 86 columnas.

# %%
# los datos de test 
df_test.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# shape
df_test.shape
# Out:
# (1459, 80)

# %% [markdown]
# El dataset de test contiene 1459 filas y 80 columnas.

# %% [markdown]
# La variable target es el sale price, mientras que las restantes seran tomadas como variables predictoras.

# %%
# variables predictoras
x = df.drop(columns=['SalePrice'])
y = df[['SalePrice']]

# %% [markdown]
# Se dividen los datos en un conjunto de test y otro de entrenamiento. Inicialmente, los datos de test seran seleccionados a partir del dataset de train, ya que para testear es necesario conocer las respuestas y evaluar el rendimiento. Esto se hace asi, considerando que el dataset de test no contiene la variable target.

# %%
# split de los datos
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Se separan las columnas numericas de las categoricas.

# %%
# extraer columnas
numerical_features = x.select_dtypes(include=['int', 'float']).columns
categorical_features =x.select_dtypes(include=['string']).columns

# verificar
print("Features numericas: ", numerical_features)
print("Features categoricas: ", categorical_features)
# Out:
# Features numericas:  Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'HasMiscFeature', 'Has_Alley',
#        'Has_Fence', 'HasMasVnrType', 'HasFireplaceQu'],
#       dtype='object')
# Features categoricas:  Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
# ...

# %% [markdown]
# A continuacion se elige los transformadores para cada tipo de columna. En la estrategia de imputacion para los datos numericos se opto por imputar con la mediana en vez de la media ya que hay bastantes datos faltantes y la mayoria de los datos no tienen distribucion normal. En terminos de escalamiento, debido a la presencia de outliers se opto por el robust scaler. Para los datos categoricos se opto por el onehotencoder

# %%
# transformadores para cada subconjunto de columnas
# numerico
numeric_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

# categorico
categoric_transformer =  Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# Posteriormente, se crea el ColumnTransformer.

# %%
# crear columntransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),  
        ('cat', categoric_transformer, categorical_features)  
    ]
)

# %% [markdown]
# ### 4. **Aplicación de modelos en el dataset original**
#
# Se entrena y ajusta el modelo de regresión lineal.

# %%
# pipeline 
model_rlineal = Pipeline(steps=[
    ('preprocessor', preprocessor),  
    ('regressor', LinearRegression())  
])

# %%
# ajustar a los datos de entrenamiento
model_rlineal.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF'...
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
# ...

# %%
# realizar predicciones
y_pred = model_rlineal.predict(x_test)

# %%
# evaluación del modelo en conjunto de prueba
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Resultados en el conjunto de prueba:")
print(f"Error absoluto medio (MAE): {mae}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Coeficiente de determinación (R²): {r2}")
# Out:
# Resultados en el conjunto de prueba:
# Error absoluto medio (MAE): 22846.53123788094
# Error cuadrático medio (MSE): 5598507563.029242
# Coeficiente de determinación (R²): 0.20010355058236506

# %%
# convertir las series a una dimension
y_test = np.ravel(y_test)
y_test_pred = np.ravel(y_pred)

# gráfico
plt.figure(figsize=(8, 8))

# valores reales vs predichos
plt.scatter(y_test, y_test_pred, alpha=0.5, color='blue', label='Predicciones')

# línea de referencia de predicción perfecta (predicho = real)
max_value = max(max(y_test), max(y_test_pred))
min_value = min(min(y_test), min(y_test_pred))
plt.plot([min_value, max_value], [min_value, max_value], color='red', linestyle='--', label='Predicción Perfecta')

# configurar gráfico
plt.title('Comparación de Datos Reales y Predichos - Regresion lineal')
plt.xlabel('Datos Reales')
plt.ylabel('Datos Predichos')
plt.legend()
plt.grid(alpha=0.3)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Se observa en las métricas y en el gráfico que el modelo de regresión lineal realiza predicciones pero con r2 muy bajo. En el gráfico se logra ver que los datos se encuentran cercanos a la linea de predicción perfecta, se nota también que ciertos inconvenientes en realizar predicciones de valores más altos y esto probablemente se deba a que la muestra de precios de casas elevados es menor en comparación a las de menor valor. Por otro lado, la métrica de R2 arroja un valor de solo 0.2, sugiriendo que se tiene una predicción mala.

# %% [markdown]
# ### **3. Preprocesamiento de datos en dataset modificado**
#
# A continuación se realizan los mismos pasos aplicados anteriormente pero utilizando el dataset modificado, con el objetivo de visualizar el rendimiento del modelo luego de las transformaciones.

# %%
# type
df_modified.dtypes
# Out:
# Id                             int64
# MSSubClass                     int64
# MSZoning              string[python]
# LotFrontage                  float64
# LotArea                        int64
#                            ...
# TotRmsAbvGrd_cubed             int64
# 1stFlrSF_squared               int64
# 1stFlrSF_cubed                 int64
# 2ndFlrSF_squared               int64
# 2ndFlrSF_cubed                 int64
# Length: 94, dtype: object

# %%
# df
df_modified.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       rl         65.0     8450   pave  Unknown      reg
# 1   2          20       rl         80.0     9600   pave  Unknown      reg
# 2   3          60       rl         68.0    11250   pave  Unknown      ir1
# 3   4          70       rl         60.0     9550   pave  Unknown      ir1
# 4   5          60       rl         84.0    14260   pave  Unknown      ir1
#
#   LandContour Utilities  ... HasMasVnrType HasFireplaceQu GrLivArea_squared  \
# 0         lvl    allpub  ...             1              0           2924100
# 1         lvl    allpub  ...             0              1           1592644
# 2         lvl    allpub  ...             1              1           3189796
# 3         lvl    allpub  ...             0              1           2948089
# 4         lvl    allpub  ...             1              1           4831204
#
# ...

# %%
# df
df_modified.shape
# Out:
# (1094, 94)

# %%
# variables predictoras
x_modified = df_modified.drop(columns=['SalePrice'])
y_modified = df_modified[['SalePrice']]

# %%
# split de los datos
x_train_m, x_test_m, y_train_m, y_test_m = train_test_split(x_modified, y_modified, test_size=0.3, random_state=42)

# %%
# extraer columnas
numerical_features = x_modified.select_dtypes(include=['int', 'float']).columns
categorical_features =x_modified.select_dtypes(include=['string']).columns

# verificar
print("Features numericas: ", numerical_features)
print("Features categoricas: ", categorical_features)
# Out:
# Features numericas:  Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'HasMiscFeature', 'Has_Alley',
#        'Has_Fence', 'HasMasVnrType', 'HasFireplaceQu', 'GrLivArea_squared',
#        'GrLivArea_cubed', 'TotRmsAbvGrd_squared', 'TotRmsAbvGrd_cubed',
#        '1stFlrSF_squared', '1stFlrSF_cubed', '2ndFlrSF_squared',
#        '2ndFlrSF_cubed'],
#       dtype='object')
# ...

# %%
# transformadores para cada subconjunto de columnas
# numerico
numeric_transformer = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler', RobustScaler())
])

# categorico
categoric_transformer =  Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
# crear columntransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),  
        ('cat', categoric_transformer, categorical_features)  
    ]
)

# %% [markdown]
# ### **4. Aplicación del modelo en el dataset modificado**
#
# Se entrena el modelo en el dataset modificado

# %%
# pipeline 
model_rlinealm = Pipeline(steps=[
    ('preprocessor', preprocessor),  
    ('regressor', LinearRegression())  
])

# %%
# ajustar a los datos de entrenamiento
model_rlinealm.fit(x_train_m, y_train_m)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    RobustScaler())]),
#                                                   Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF'...
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
# ...

# %%
# realizar predicciones
y_pred_m = model_rlinealm.predict(x_test_m)

# %%
# evaluación del modelo en conjunto de prueba
mae = mean_absolute_error(y_test_m, y_pred_m)
mse = mean_squared_error(y_test_m, y_pred_m)
r2 = r2_score(y_test_m, y_pred_m)

print("Resultados en el conjunto de prueba:")
print(f"Error absoluto medio (MAE): {mae}")
print(f"Error cuadrático medio (MSE): {mse}")
print(f"Coeficiente de determinación (R²): {r2}")
# Out:
# Resultados en el conjunto de prueba:
# Error absoluto medio (MAE): 0.09783783569597648
# Error cuadrático medio (MSE): 0.05117604806347634
# Coeficiente de determinación (R²): 0.6727421002798215

# %%
# convertir las series a una dimension
y_test_m = np.ravel(y_test_m)
y_test_pred_m = np.ravel(y_pred_m)

# gráfico
plt.figure(figsize=(8, 8))

# valores reales vs predichos
plt.scatter(y_test_m, y_test_pred_m, alpha=0.5, color='blue', label='Predicciones')

# línea de referencia de predicción perfecta (predicho = real)
max_value = max(max(y_test_m), max(y_test_pred_m))
min_value = min(min(y_test_pred_m), min(y_test_pred_m))
plt.plot([min_value, max_value], [min_value, max_value], color='red', linestyle='--', label='Predicción Perfecta')

# configurar gráfico
plt.title('Comparación de Datos Reales y Predichos - Regresion lineal')
plt.xlabel('Datos Reales')
plt.ylabel('Datos Predichos')
plt.legend()
plt.grid(alpha=0.3)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Utilizando transformaciones se logra observar que el modelo de regresion lineal mejora considerablemente, arrojando valores de 0.67 para r2. Esto podria mejorarse aun mas aplicando mas transformaciones y generando nuevas variables a partir de las ya existentes.
